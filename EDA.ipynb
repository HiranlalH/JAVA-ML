# %%
import pandas as pd
import numpy as np

# %%
cldf = pd.read_csv("clndData.csv")
cldf
# Out:
#            Ship Mode Customer ID     Customer Name    Segment        Country  \
# 0       Second Class    CG-12520       Claire Gute   Consumer  United States
# 1       Second Class    CG-12520       Claire Gute   Consumer  United States
# 2       Second Class    DV-13045   Darrin Van Huff  Corporate  United States
# 3     Standard Class    SO-20335    Sean O'Donnell   Consumer  United States
# 4     Standard Class    SO-20335    Sean O'Donnell   Consumer  United States
# ...              ...         ...               ...        ...            ...
# 9929    Second Class    TB-21400  Tom Boeckenhauer   Consumer  United States
# 9930  Standard Class    DB-13060       Dave Brooks   Consumer  United States
# 9931  Standard Class    DB-13060       Dave Brooks   Consumer  United States
# 9932  Standard Class    DB-13060       Dave Brooks   Consumer  United States
# 9933    Second Class    CC-12220      Chris Cortes   Consumer  United States
#
# ...

# %%
cldf.isnull().sum()
# Out:
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
cldf.columns
# Out:
# Index(['Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#Info of each column,data type,count of null values

print("============information=========")
cldf.info()
# Out:
# ============information=========
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9934 entries, 0 to 9933
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ship Mode      9934 non-null   object
#  1   Customer ID    9934 non-null   object
#  2   Customer Name  9934 non-null   object
#  3   Segment        9934 non-null   object
#  4   Country        9934 non-null   object
#  5   City           9934 non-null   object
#  6   State          9934 non-null   object
#  7   Postal Code    9934 non-null   int64
#  8   Region         9934 non-null   object
#  9   Product ID     9934 non-null   object
#  10  Category       9934 non-null   object
#  11  Sub-Category   9934 non-null   object
#  12  Product Name   9934 non-null   object
#  13  Sales          9934 non-null   float64
#  14  Quantity       9934 non-null   float64
#  15  Discount       9934 non-null   float64
# ...

# %%
# Sales by Category (Bar Charts):

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Sales', data=cldf)
plt.title('Sales by Category')
plt.show()

# %%
# Profit by Category (Bar Charts):

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Profit', data=cldf)
plt.title('Profit by Category')
plt.show()

# %%
#Sales by Region (Pie Chart):
sales_by_region = cldf.groupby('Region')['Sales'].sum()

plt.figure(figsize=(8, 8))
sales_by_region.plot.pie(autopct='%1.1f%%')
plt.title('Sales by Region')
plt.ylabel('')
plt.show()

# %%
# Distribution of Sales (Histogram)

plt.figure(figsize=(10, 6))
sns.histplot(cldf['Sales'], bins=30, kde=True)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.show()

# %%
# Distribution of Profit(Histogram)

plt.figure(figsize=(10, 6))
sns.histplot(cldf['Profit'], bins=30, kde=True)
plt.title('Distribution of Profit')
plt.xlabel('Profit')
plt.show()

# %%
# Sales vs. Profit (Scatter Plot)

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sales', y='Profit', data=cldf)
plt.title('Sales vs. Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()
import numpy as np
